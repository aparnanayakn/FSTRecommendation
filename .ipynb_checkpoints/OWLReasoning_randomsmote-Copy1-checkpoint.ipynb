# %%
import pandas as pd
import jenkspy
import numpy as np
from owlready2 import *
import ast 
import rdflib
import re

owlready2.JAVA_EXE ="/usr/lib/jvm/java-17-openjdk-amd64/bin/java"

onto = get_ontology("file:///home/d19125691/Documents/Experiments/ontologyDCQ/onto-DCQ-FS_git/onto/MtLv2.owl").load()
#onto = get_ontology("file:///home/d19125691/Documents/Experiments/ontologyDCQ/onto-DCQ-FS_git/MtL_Enriched.owl").load()

dcat = get_namespace("http://www.w3.org/ns/dcat/")
dqv = get_namespace("http://www.w3.org/ns/dqv/")
mtl = get_ontology("https://purl.archive.org/domain/mtl#")
#onto.base_iri = "https://purl.archive.org/domain/mtl#"
rdf=get_namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
dmop = get_ontology("http://www.e-lico.eu/ontologies/dmo/DMOP/DMOP.owl")
dmop.base_iri = "http://www.e-lico.eu/ontologies/dmo/DMOP/DMOP.owl#"
dmop1 = get_ontology("http://www.e-LICO.eu/ontologies/dmo/DMOP/DMOP.owl")
dmop1.base_iri = "http://www.e-LICO.eu/ontologies/dmo/DMOP/DMOP.owl#"
pd1 = get_ontology("http://www.e-lico.eu/ontologies/dmo/DMOP/PD.owl")
pd1.base_iri = "http://www.e-lico.eu/ontologies/dmo/DMOP/PD.owl#"

#sync_reasoner_pellet([onto], infer_property_values=True, infer_data_property_values=True)
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %%
with onto:
    #MI
    #(nr_inst <= 167.000) and (eigenvalues.mean > 30.208) and (nr_inst > 95.000) and (attr_conc.mean > 0.053)	MI
    float_lt_167 = ConstrainedDatatype(float, max_inclusive = 167.0)
    float_gt_950 = ConstrainedDatatype(float, min_exclusive = 95.0)
    float_gt_308 = ConstrainedDatatype(float, min_exclusive = 30.208)         
    float_gt_053 = ConstrainedDatatype(float, min_exclusive = 0.053)        

    #Relief
    #(nr_inst > 167.000) and (nUnique > 6.500) and (nr_cor_attr <= 0.052) and (g_mean.mean > 0.221)	relief
    float_gt_167 = ConstrainedDatatype(float, min_exclusive = 167.0)
    float_gt_650 = ConstrainedDatatype(float, min_exclusive = 6.5)
    float_lt_052 = ConstrainedDatatype(float, max_inclusive = 0.052)         
    float_gt_221 = ConstrainedDatatype(float, min_exclusive = 0.221)    
    float_lt_112 = ConstrainedDatatype(float, max_inclusive = 11.271)
    float_gt_016 = ConstrainedDatatype(float, min_exclusive = 0.016)
    float_gt_425 = ConstrainedDatatype(float, min_exclusive = 0.425)
    float_gt_380 = ConstrainedDatatype(float, min_exclusive = -38.058)
    float_lt_224 = ConstrainedDatatype(float, max_inclusive = 2.249)

    #GR
    #(nr_inst > 167.000) and (nr_inst <= 347.000) and (nUnique <= 4.500) and (t_mean.mean > 11.271) 
    # and (LabelIssuesPerc <= 0.061) and (ena > -7.065)
    float_lt_347 = ConstrainedDatatype(float, max_inclusive = 347.00) 
    float_lt_450 = ConstrainedDatatype(float, max_inclusive = 4.5) 
    float_gt_112 = ConstrainedDatatype(float, min_exclusive = 11.271)
    float_lt_061 = ConstrainedDatatype(float, max_inclusive = 0.061)
    float_gt_706 = ConstrainedDatatype(float, min_exclusive = -7.065)

    #FCBF
    #(nr_inst > 167.000) and (nUnique <= 6.500) and (ena > -9.286) and (Conciseness > 0.219) and (Conciseness <= 0.404)
    float_lt_650 = ConstrainedDatatype(float, max_inclusive = 6.5)
    float_gt_928 =  ConstrainedDatatype(float, min_exclusive = -9.286)
    float_gt_219 =  ConstrainedDatatype(float, min_exclusive = 0.219)
    float_lt_404 =  ConstrainedDatatype(float, max_inclusive = 0.404)

    #Chisquare
    #nr_inst > 167.000) and (nUnique <= 6.500) and (ena > -9.286) and (Conciseness <= 0.219) and (attr_ent.mean <= 2.674) and (cEntropy <= 0.948) and (range.mean > 0.692) and (attr_to_inst <= 0.065)	chisquare
    float_lt_219 =  ConstrainedDatatype(float, max_inclusive = 0.219)
    float_lt_267 =  ConstrainedDatatype(float, max_inclusive = 2.674)
    float_lt_948 =  ConstrainedDatatype(float, max_inclusive = 0.948)
    float_gt_692 = ConstrainedDatatype(float, min_exclusive = 0.692)
    float_lt_065 =  ConstrainedDatatype(float, max_inclusive = 0.065)


    #MI value constraints
    class MIConstraintsInstances1(mtl.Mean):
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_lt_167)]

    class MIConstraintsInstances2(mtl.Mean): # MIMean1
        equivalent_to = [ MIConstraintsInstances1 &
        mtl.hasDatavalue.some(float_gt_950)]

    class MIConstraintsEigen(mtl.Mean): #MIMean2
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_gt_308)]             

    class MIConstraintsAttr(mtl.Mean): #MIMean3
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_gt_053)]   
    
    #Relief constraints

    class ReliefConstraintsInstances(mtl.Mean): #ReliefMean1
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_gt_167)]
    
    AllDisjoint([MIConstraintsInstances1, ReliefConstraintsInstances])

    class ReliefConstraintsNoClasses(mtl.Mean): #ReliefMean2
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_gt_650)]
    
    class ReliefNumberofCorr(mtl.Mean):  #ReliefMean3
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_lt_052)]
    
    class ReliefGMean(mtl.Mean): #ReliefMean4
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_221)]
    
    class ReliefConstraintsTMean(mtl.Mean): #ReliefMean5
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_lt_112)]

    class ReliefConstraintsNoOfOutliers(mtl.Mean): #ReliefMean6
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_016)]

    class ReliefConstraintsCEntropy(mtl.Mean): #ReliefMean7
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_425)]
    
    class ReliefConstraintsENA1(mtl.Mean): 
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_380)]
    
    class ReliefConstraintsENA2(mtl.Mean): #ReliefMean8
        equivalent_to = [ReliefConstraintsENA1 & mtl.hasDatavalue.some(float_lt_224)]

    #GR constraints
    class GRConstraintsInstances2(mtl.Mean): #GRMean1
        equivalent_to = [ ReliefConstraintsInstances &
        mtl.hasDatavalue.some(float_lt_347)]
    
    class GRConstraintsNoClasses(mtl.Mean): #GRMean2
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_lt_450)]
    
    class GRConstrainsTMean(mtl.Mean): #GRMean3
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_112)]

    AllDisjoint([GRConstrainsTMean, ReliefConstraintsTMean])

    class GRConstrainsLabelIssuesPerc(mtl.Mean): #GRMean4
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_lt_061)]
    
    class GRConstraintsENA(mtl.Mean): #GRMean5
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_706)]

    #FCBF
    class FCBFConstraintsNoClasses(mtl.Mean): #FCBFMean1
        equivalent_to = [ mtl.Mean &
        mtl.hasDatavalue.some(float_lt_650)]
    
    AllDisjoint([FCBFConstraintsNoClasses, ReliefConstraintsNoClasses])

    class FCBFConstraintsENA(mtl.Mean): #FCBFMean2
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_928)]
    
    class FCBFConstraintsConc1(mtl.Mean): 
        equivalent_to = [mtl.Mean & mtl.hasDatavalue.some(float_gt_219)]

    class FCBFConstraintsConc2(mtl.Mean): #FCBFMean3
        equivalent_to = [mtl.FCBFConstraintsConc1 & mtl.hasDatavalue.some(float_lt_404)]

    #Chisquare
    #    
    class ChisquareConstraintsConc(mtl.Mean):#CMean1
        equivalent_to = [ mtl.Mean & mtl.hasDatavalue.some(float_lt_219)   ]
    
    AllDisjoint([FCBFConstraintsConc1, ChisquareConstraintsConc])

    class ChisquareConstraintsAttrEnt(mtl.Mean): #CMean2
        equivalent_to = [ mtl.Mean & mtl.hasDatavalue.some(float_lt_267) ]

    class ChisquareConstraintsCEnt(mtl.Mean): #CMean3
        equivalent_to = [ mtl.Mean & mtl.hasDatavalue.some(float_lt_948) ]

    class ChisquareConstraintsRange(mtl.Mean): #CMean4
        equivalent_to = [ mtl.Mean & mtl.hasDatavalue.some(float_gt_692) ]

    class ChisquareConstraintsAttrInst(mtl.Mean): #CMean5
        equivalent_to = [ mtl.Mean & mtl.hasDatavalue.some(float_lt_065) ]

    #MI  mean
    class MIMean1(dmop1.DataCharacteristic):
        equivalent_to = [
        dmop1.NumberOfInstances & mtl.qlocation.some(mtl.MIConstraintsInstances2)
    ]

    class MIMean2(dmop1.DataCharacteristic):
        equivalent_to = [
            mtl.EigenValues & mtl.qlocation.some(mtl.MIConstraintsEigen) ]

    class MIMean3(dmop1.DataCharacteristic):
        equivalent_to = [
            mtl.AttributeConcentration & mtl.qlocation.some(mtl.MIConstraintsAttr) ]  

    #Relief  mean
    class ReliefMean1(dmop1.DataCharacteristic): 
        equivalent_to = [
        dmop1.NumberOfInstances & mtl.qlocation.some(mtl.ReliefConstraintsInstances)
    ]
    
    class ReliefMean2(dmop1.DataCharacteristic):
        equivalent_to = [
            mtl.NumberOfClasses & mtl.qlocation.some(mtl.ReliefConstraintsNoClasses) ]

    class ReliefMean3(dmop1.DataCharacteristic):
        equivalent_to = [
            mtl.NumberOfHighlyCorrelatedAttributes & mtl.qlocation.some(mtl.ReliefNumberofCorr) ]

    class ReliefMean4(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.GeometricMean & mtl.qlocation.some(mtl.ReliefGMean)
    ]

    class ReliefMean5(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.TrimmedMean & mtl.qlocation.some(mtl.ReliefConstraintsTMean)
    ]

    class ReliefMean6(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.OutlierDetection & mtl.qlocation.some(mtl.ReliefConstraintsNoOfOutliers)
        ]
    
    class ReliefMean7(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.ClassEntropy & mtl.qlocation.some(mtl.ReliefConstraintsCEntropy) ] 
    
    class ReliefMean8(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.EqNumberOfAttributes & mtl.qlocation.some(mtl.ReliefConstraintsENA2) ] 

    #GR mean
    class GRMean1(dmop1.DataCharacteristic):
        equivalent_to = [
        dmop1.NumberOfInstances & mtl.qlocation.some(mtl.GRConstraintsInstances2)
    ]

    class GRMean2(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.NumberOfClasses & mtl.qlocation.some(mtl.GRConstraintsNoClasses)
    ]

    class GRMean3(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.TrimmedMean & mtl.qlocation.some(mtl.GRConstrainsTMean)
    ]

    class GRMean4(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.LabelNoise & mtl.qlocation.some(mtl.GRConstrainsLabelIssuesPerc)
    ]

    class GRMean5(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.EqNumberOfAttributes & mtl.qlocation.some(mtl.GRConstraintsENA)
    ]

    #FCBF
    class FCBFMean1(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.NumberOfClasses & mtl.qlocation.some(mtl.FCBFConstraintsNoClasses)
    ]

    class FCBFMean2(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.EqNumberOfAttributes & mtl.qlocation.some(mtl.FCBFConstraintsENA)
    ]

    class FCBFMean3(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.Conciseness & mtl.qlocation.some(mtl.FCBFConstraintsConc2)
    ]

    #Chisquare
    class ChisquareMean1(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.Conciseness & mtl.qlocation.some(mtl.ChisquareConstraintsConc)    ]

    class ChisquareMean2(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.AttributesEntropy & mtl.qlocation.some(mtl.ChisquareConstraintsAttrEnt)    ]

    class ChisquareMean3(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.ClassEntropy & mtl.qlocation.some(mtl.ChisquareConstraintsCEnt)    ]

    class ChisquareMean4(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.Range & mtl.qlocation.some(mtl.ChisquareConstraintsRange)    ]

    class ChisquareMean5(dmop1.DataCharacteristic):
        equivalent_to = [
        mtl.ProportionOfAttrToInstances & mtl.qlocation.some(mtl.ChisquareConstraintsAttrInst)    ]    

    #MI dataset
    class MIRelevantData(dmop.LabeledDataSet):
        equivalent_to = [ dmop.LabeledDataSet &
            mtl.hasQuality.some(mtl.MIMean1) & mtl.hasQuality.some(mtl.MIMean2) & mtl.hasQuality.some(mtl.MIMean3)  
        ]      
    
    #Relief
    class Relief1RelevantData(dmop.LabeledDataSet):
        equivalent_to = [ dmop.LabeledDataSet &
            mtl.hasQuality.some(mtl.ReliefMean1) & mtl.hasQuality.some(mtl.ReliefMean2) & 
            mtl.hasQuality.some(mtl.ReliefMean3)  & mtl.hasQuality.some(mtl.ReliefMean4)    
        ]

    class Relief2RelevantData(dmop.LabeledDataSet):
        equivalent_to = [ dmop.LabeledDataSet &
            mtl.hasQuality.some(mtl.GRMean1) & mtl.hasQuality.some(mtl.GRMean2) & 
            mtl.hasQuality.some(mtl.ReliefMean5)  & mtl.hasQuality.some(mtl.ReliefMean6) & 
            mtl.hasQuality.some(mtl.ReliefMean7)  & mtl.hasQuality.some(mtl.ReliefMean8)    
        ]


    #GR
    class GRRelevantData(dmop.LabeledDataSet):
        equivalent_to = [ dmop.LabeledDataSet &
            mtl.hasQuality.some(mtl.GRMean1) & mtl.hasQuality.some(mtl.GRMean2) & mtl.hasQuality.some(mtl.GRMean3)  
            & mtl.hasQuality.some(mtl.GRMean4) & mtl.hasQuality.some(mtl.GRMean5)
        ]

    #FCBF
    class FCBFRelevantData(dmop.LabeledDataSet):
        equivalent_to = [ dmop.LabeledDataSet &
            mtl.hasQuality.some(mtl.FCBFMean1) & mtl.hasQuality.some(mtl.FCBFMean2) & mtl.hasQuality.some(mtl.FCBFMean3)  
            & mtl.hasQuality.some(mtl.ReliefMean1)
        ]
    
    #Chisquare
    class ChisquareRelevantData(dmop.LabeledDataSet):
        equivalent_to = [ dmop.LabeledDataSet &
            mtl.hasQuality.some(mtl.ChisquareMean1) & mtl.hasQuality.some(mtl.ChisquareMean2) & 
            mtl.hasQuality.some(mtl.ChisquareMean3)  & mtl.hasQuality.some(mtl.ChisquareMean4) &
             mtl.hasQuality.some(mtl.ChisquareMean5) & 
            mtl.hasQuality.some(mtl.FCBFMean1) &  mtl.hasQuality.some(mtl.FCBFMean2)
            & mtl.hasQuality.some(mtl.ReliefMean1)
        ]

    #MI Task
    class MITask(mtl.FeatureSelectionRecommendationTask):
        equivalent_to = [
        mtl.FeatureSelectionRecommendationTask &
        dmop.specifiesInputClass.exactly(1, mtl.MIRelevantData) &
        dmop.specifiesOutputClass.exactly(1,mtl.MIRecommendation)]


    #Chisquare Task
    class ChisquareTask(mtl.FeatureSelectionRecommendationTask):
        equivalent_to = [
        mtl.FeatureSelectionRecommendationTask &
        dmop.specifiesInputClass.exactly(1, mtl.ChisquareRelevantData) &
        dmop.specifiesOutputClass.exactly(1,mtl.ChisquareRecommendation)
    ]  

    mtl.MIRecommendation.recommends.append(mtl.MutualInformation)
    mtl.ChisquareRecommendation.recommends.append(mtl.ChiSquare)
close_world([onto])

# %%
onto.save("pop.rdf",format="rdfxml")

# %%
def convert_and_round(value):
    try:
        return float(value)
    except (ValueError, TypeError):
        return value  

df = pd.read_csv("test_dataset.csv")
df.fillna(0,inplace=True)
for col in df.columns:
    df[col] = df[col].apply(convert_and_round)

pattern = re.compile(r'[^a-zA-Z0-9]') #removing non-alpha numeric characters from file name

fileObjects = {}
df.shape
# Out:
# (35, 41)

# %%
def add_featurevalue(fileObject, feature_class, mean_name, value):
    feature = feature_class(mean_name + "_feature", namespace=onto)
    mean = mtl.Mean(mean_name + "_mean", namespace=onto)
    feature.qlocation.append(mean)
    mean.hasDatavalue = [value]
    fileObject.hasQuality.append(feature)

# %%
with onto:
    for i in range(5):
  #      i=34
        fileName = df['File'][i]
        fileName = pattern.sub('', fileName)

        mtla = mtl.LearningFromTaskProperties(fileName, namespace=onto)
        mtlt = mtl.FeatureSelectionRecommendationTask(fileName, namespace=onto)

        fileObject = dmop.LabeledDataSet(fileName, namespace=onto)
        fileObjects[fileName] = mtlt
        fsr_output = mtl.FeatureSelectionRecommendation(fileName, namespace=onto)
        mtla.addresses.append(mtlt)

        mtlt.specifiesInputClass = [fileObject]
        mtlt.specifiesOutputClass = [fsr_output]

        add_featurevalue(fileObject, dmop1.NumberOfInstances, fileName+'_nrInst', int(df['nr_inst'][i]))
        add_featurevalue(fileObject, mtl.EigenValues, fileName + "_eigen", float(df['eigenvalues.mean'][i]))
        add_featurevalue(fileObject, mtl.AttributeConcentration, fileName + "_attrconc", float(df['attr_conc.mean'][i]))
        add_featurevalue(fileObject, mtl.EigenValues, fileName + "_eigen", float(df['eigenvalues.mean'][i]))
        add_featurevalue(fileObject, mtl.NumberOfClasses, fileName+'_nunique', int(df['nUnique'][i]))
        add_featurevalue(fileObject, mtl.NumberOfHighlyCorrelatedAttributes, fileName + "_nrcorattr", float(df['nr_cor_attr'][i]))
        add_featurevalue(fileObject, mtl.GeometricMean, fileName + "_gmean", float(df['g_mean.mean'][i]))
        add_featurevalue(fileObject, mtl.AttributesEntropy, fileName + "_attrent", float(df['attr_ent.mean'][i]))
        add_featurevalue(fileObject, mtl.EqNumberOfAttributes, fileName+'_ena', float(df['ena'][i]))
        add_featurevalue(fileObject, mtl.LabelNoise, fileName + "_labelissuesperc", float(df['LabelIssuesPerc'][i]))
        add_featurevalue(fileObject, mtl.ProportionOfAttrToInstances, fileName + "_attrinst", float(df['attr_to_inst'][i]))
        add_featurevalue(fileObject, mtl.Range, fileName + "_range", float(df['range.mean'][i]))
        add_featurevalue(fileObject, mtl.ClassEntropy, fileName + "_centropy", float(df['cEntropy'][i]))
        add_featurevalue(fileObject, mtl.Conciseness, fileName + "_conciseness", float(df['Conciseness'][i]))
        add_featurevalue(fileObject, mtl.TrimmedMean, fileName + "_tmean", float(df['t_mean.mean'][i]))

    # AllDifferent([q2,q3,q4,q5,q6,q7,q8,q9,q10,q11,q12,q13,q14,q15])
close_world([onto])

# %%
try:    
    sync_reasoner_pellet([onto], infer_property_values=True, infer_data_property_values=True)
    print("✅ Ontology is consistent.")
except OwlReadyInconsistentOntologyError:
    print("❌ Ontology inconsistent! Checking problem individuals...")
    for ind in onto.individuals():
        if ind.is_instance_of:
            print(f"Individual: {ind}, Classes: {ind.is_instance_of}")
except Exception as e:
    print("Reasoner failed:", e)
# Out:
# * Owlready2 * Running Pellet...
#     /usr/lib/jvm/java-17-openjdk-amd64/bin/java -Xmx2000M -cp /home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/xercesImpl-2.10.0.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/jgrapht-jdk1.5.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/jcl-over-slf4j-1.6.4.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/xml-apis-1.4.01.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/httpclient-4.2.3.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/commons-codec-1.6.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/antlr-3.2.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/jena-core-2.10.0.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/jena-arq-2.10.0.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/httpcore-4.2.2.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/slf4j-api-1.6.4.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/log4j-1.2.16.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/jena-tdb-0.10.0.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/antlr-runtime-3.2.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/jena-iri-0.9.5.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/owlapi-distribution-3.4.3-bin.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/pellet-2.3.1.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/aterm-java-1.6.jar:/home/d19125691/.local/lib/python3.6/site-packages/owlready2/pellet/slf4j-log4j12-1.6.4.jar pellet.Pellet realize --loader Jena --input-format N-Triples --infer-prop-values --infer-data-prop-values --ignore-imports /tmp/tmpe2lqqkan
# * Owlready * Adding relation MtLv2.HTRU2csv_eigen_feature immediate-relation MtLv2.HTRU2csv_eigen_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_eigen_feature q-location MtLv2.HTRU2csv_eigen_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nrInst_feature immediate-relation MtLv2.ckddatasetv2csv_nrInst_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nrInst_feature q-location MtLv2.ckddatasetv2csv_nrInst_mean
# * Owlready * Adding relation MtLv2.ecolidata_gmean_feature immediate-relation MtLv2.ecolidata_gmean_mean
# * Owlready * Adding relation MtLv2.ecolidata_gmean_feature q-location MtLv2.ecolidata_gmean_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_range_feature immediate-relation MtLv2.pageblocks5cn01nccsv_range_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_range_feature q-location MtLv2.pageblocks5cn01nccsv_range_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_ena_feature immediate-relation MtLv2.yeast2vs4csv_ena_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_ena_feature q-location MtLv2.yeast2vs4csv_ena_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_attrent_feature immediate-relation MtLv2.HTRU2csv_attrent_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_attrent_feature q-location MtLv2.HTRU2csv_attrent_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_range_feature immediate-relation MtLv2.HTRU2csv_range_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_range_feature q-location MtLv2.HTRU2csv_range_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_conciseness_feature immediate-relation MtLv2.yeast2vs4csv_conciseness_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_conciseness_feature q-location MtLv2.yeast2vs4csv_conciseness_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_labelissuesperc_feature immediate-relation MtLv2.ckddatasetv2csv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_labelissuesperc_feature q-location MtLv2.ckddatasetv2csv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_tmean_feature immediate-relation MtLv2.ckddatasetv2csv_tmean_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_tmean_feature q-location MtLv2.ckddatasetv2csv_tmean_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_gmean_feature immediate-relation MtLv2.ckddatasetv2csv_gmean_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_gmean_feature q-location MtLv2.ckddatasetv2csv_gmean_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_gmean_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_eigen_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_centropy_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_attrconc_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_ena_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_nrInst_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_attrent_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_tmean_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_attrinst_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_conciseness_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_range_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv immediate-relation-i MtLv2.yeast2vs4csv_nunique_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_gmean_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_eigen_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_centropy_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_attrconc_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_ena_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_nrInst_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_attrent_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_tmean_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_attrinst_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_conciseness_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_range_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv has-quality MtLv2.yeast2vs4csv_nunique_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_conciseness_feature immediate-relation MtLv2.pageblocks5cn01nccsv_conciseness_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_conciseness_feature q-location MtLv2.pageblocks5cn01nccsv_conciseness_mean
# * Owlready * Adding relation MtLv2.ecolidata_centropy_feature immediate-relation MtLv2.ecolidata_centropy_mean
# * Owlready * Adding relation MtLv2.ecolidata_centropy_feature q-location MtLv2.ecolidata_centropy_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrent_feature immediate-relation MtLv2.yeast2vs4csv_attrent_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrent_feature q-location MtLv2.yeast2vs4csv_attrent_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_nrcorattr_feature immediate-relation MtLv2.HTRU2csv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_nrcorattr_feature q-location MtLv2.HTRU2csv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_range_feature immediate-relation MtLv2.yeast2vs4csv_range_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_range_feature q-location MtLv2.yeast2vs4csv_range_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_tmean_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_attrinst_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_nrInst_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_gmean_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_centropy_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_nunique_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_attrent_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_ena_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_attrconc_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_conciseness_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_range_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv immediate-relation-i MtLv2.ckddatasetv2csv_eigen_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_tmean_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_attrinst_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_nrInst_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_gmean_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_centropy_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_nunique_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_attrent_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_ena_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_attrconc_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_conciseness_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_range_feature
# * Owlready * Adding relation MtLv2.ckddatasetv2csv has-quality MtLv2.ckddatasetv2csv_eigen_feature
# * Owlready * Adding relation MtLv2.yeast2vs4csv_gmean_feature immediate-relation MtLv2.yeast2vs4csv_gmean_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_gmean_feature q-location MtLv2.yeast2vs4csv_gmean_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrinst_feature immediate-relation MtLv2.ckddatasetv2csv_attrinst_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrinst_feature q-location MtLv2.ckddatasetv2csv_attrinst_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nunique_feature immediate-relation MtLv2.pageblocks5cn01nccsv_nunique_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nunique_feature q-location MtLv2.pageblocks5cn01nccsv_nunique_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_labelissuesperc_feature immediate-relation MtLv2.yeast2vs4csv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_labelissuesperc_feature q-location MtLv2.yeast2vs4csv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nunique_feature immediate-relation MtLv2.ckddatasetv2csv_nunique_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nunique_feature q-location MtLv2.ckddatasetv2csv_nunique_mean
# * Owlready * Adding relation MtLv2.ecolidata_nunique_feature immediate-relation MtLv2.ecolidata_nunique_mean
# * Owlready * Adding relation MtLv2.ecolidata_nunique_feature q-location MtLv2.ecolidata_nunique_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_centropy_feature immediate-relation MtLv2.yeast2vs4csv_centropy_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_centropy_feature q-location MtLv2.yeast2vs4csv_centropy_mean
# * Owlready * Adding relation MtLv2.ecolidata_range_feature immediate-relation MtLv2.ecolidata_range_mean
# * Owlready * Adding relation MtLv2.ecolidata_range_feature q-location MtLv2.ecolidata_range_mean
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_nrcorattr_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_gmean_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_ena_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_nunique_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_attrconc_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_range_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_conciseness_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_centropy_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_tmean_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_eigen_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_attrinst_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_attrent_feature
# * Owlready * Adding relation MtLv2.ecolidata immediate-relation-i MtLv2.ecolidata_nrInst_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_nrcorattr_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_gmean_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_ena_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_nunique_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_attrconc_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_range_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_conciseness_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_centropy_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_tmean_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_eigen_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_attrinst_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_attrent_feature
# * Owlready * Adding relation MtLv2.ecolidata has-quality MtLv2.ecolidata_nrInst_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_gmean_feature immediate-relation MtLv2.pageblocks5cn01nccsv_gmean_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_gmean_feature q-location MtLv2.pageblocks5cn01nccsv_gmean_mean
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_eigen_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_gmean_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_nunique_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_tmean_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_attrinst_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_nrInst_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_attrent_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_attrconc_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_ena_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_range_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_centropy_feature
# * Owlready * Adding relation MtLv2.HTRU2csv immediate-relation-i MtLv2.HTRU2csv_conciseness_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_eigen_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_gmean_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_nunique_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_tmean_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_attrinst_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_nrInst_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_attrent_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_attrconc_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_ena_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_range_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_centropy_feature
# * Owlready * Adding relation MtLv2.HTRU2csv has-quality MtLv2.HTRU2csv_conciseness_feature
# * Owlready * Adding relation MtLv2.ecolidata_attrinst_feature immediate-relation MtLv2.ecolidata_attrinst_mean
# * Owlready * Adding relation MtLv2.ecolidata_attrinst_feature q-location MtLv2.ecolidata_attrinst_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_eigen_feature immediate-relation MtLv2.ckddatasetv2csv_eigen_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_eigen_feature q-location MtLv2.ckddatasetv2csv_eigen_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrent_feature immediate-relation MtLv2.pageblocks5cn01nccsv_attrent_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrent_feature q-location MtLv2.pageblocks5cn01nccsv_attrent_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_tmean_feature immediate-relation MtLv2.HTRU2csv_tmean_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_tmean_feature q-location MtLv2.HTRU2csv_tmean_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_ena_feature immediate-relation MtLv2.pageblocks5cn01nccsv_ena_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_ena_feature q-location MtLv2.pageblocks5cn01nccsv_ena_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_ena_feature immediate-relation MtLv2.HTRU2csv_ena_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_ena_feature q-location MtLv2.HTRU2csv_ena_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrinst_feature immediate-relation MtLv2.yeast2vs4csv_attrinst_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrinst_feature q-location MtLv2.yeast2vs4csv_attrinst_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_range_feature immediate-relation MtLv2.ckddatasetv2csv_range_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_range_feature q-location MtLv2.ckddatasetv2csv_range_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_tmean_feature immediate-relation MtLv2.pageblocks5cn01nccsv_tmean_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_tmean_feature q-location MtLv2.pageblocks5cn01nccsv_tmean_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_labelissuesperc_feature immediate-relation MtLv2.pageblocks5cn01nccsv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_labelissuesperc_feature q-location MtLv2.pageblocks5cn01nccsv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_gmean_feature immediate-relation MtLv2.HTRU2csv_gmean_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_gmean_feature q-location MtLv2.HTRU2csv_gmean_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_tmean_feature immediate-relation MtLv2.yeast2vs4csv_tmean_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_tmean_feature q-location MtLv2.yeast2vs4csv_tmean_mean
# * Owlready * Adding relation MtLv2.ecolidata_labelissuesperc_feature immediate-relation MtLv2.ecolidata_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.ecolidata_labelissuesperc_feature q-location MtLv2.ecolidata_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_attrconc_feature immediate-relation MtLv2.HTRU2csv_attrconc_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_attrconc_feature q-location MtLv2.HTRU2csv_attrconc_mean
# * Owlready * Adding relation MtLv2.ecolidata_tmean_feature immediate-relation MtLv2.ecolidata_tmean_mean
# * Owlready * Adding relation MtLv2.ecolidata_tmean_feature q-location MtLv2.ecolidata_tmean_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nrcorattr_feature immediate-relation MtLv2.pageblocks5cn01nccsv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nrcorattr_feature q-location MtLv2.pageblocks5cn01nccsv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_eigen_feature immediate-relation MtLv2.pageblocks5cn01nccsv_eigen_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_eigen_feature q-location MtLv2.pageblocks5cn01nccsv_eigen_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_centropy_feature immediate-relation MtLv2.pageblocks5cn01nccsv_centropy_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_centropy_feature q-location MtLv2.pageblocks5cn01nccsv_centropy_mean
# * Owlready * Adding relation MtLv2.ecolidata_attrent_feature immediate-relation MtLv2.ecolidata_attrent_mean
# * Owlready * Adding relation MtLv2.ecolidata_attrent_feature q-location MtLv2.ecolidata_attrent_mean
# * Owlready * Adding relation MtLv2.ecolidata_nrInst_feature immediate-relation MtLv2.ecolidata_nrInst_mean
# * Owlready * Adding relation MtLv2.ecolidata_nrInst_feature q-location MtLv2.ecolidata_nrInst_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_centropy_feature immediate-relation MtLv2.ckddatasetv2csv_centropy_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_centropy_feature q-location MtLv2.ckddatasetv2csv_centropy_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nrcorattr_feature immediate-relation MtLv2.yeast2vs4csv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nrcorattr_feature q-location MtLv2.yeast2vs4csv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_eigen_feature immediate-relation MtLv2.yeast2vs4csv_eigen_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_eigen_feature q-location MtLv2.yeast2vs4csv_eigen_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_attrinst_feature immediate-relation MtLv2.HTRU2csv_attrinst_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_attrinst_feature q-location MtLv2.HTRU2csv_attrinst_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrconc_feature immediate-relation MtLv2.yeast2vs4csv_attrconc_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrconc_feature q-location MtLv2.yeast2vs4csv_attrconc_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nrcorattr_feature immediate-relation MtLv2.ckddatasetv2csv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nrcorattr_feature q-location MtLv2.ckddatasetv2csv_nrcorattr_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_ena_feature immediate-relation MtLv2.ckddatasetv2csv_ena_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_ena_feature q-location MtLv2.ckddatasetv2csv_ena_mean
# * Owlready * Adding relation MtLv2.ecolidata_conciseness_feature immediate-relation MtLv2.ecolidata_conciseness_mean
# * Owlready * Adding relation MtLv2.ecolidata_conciseness_feature q-location MtLv2.ecolidata_conciseness_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrconc_feature immediate-relation MtLv2.ckddatasetv2csv_attrconc_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrconc_feature q-location MtLv2.ckddatasetv2csv_attrconc_mean
# * Owlready * Adding relation MtLv2.ecolidata_eigen_feature immediate-relation MtLv2.ecolidata_eigen_mean
# * Owlready * Adding relation MtLv2.ecolidata_eigen_feature q-location MtLv2.ecolidata_eigen_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrinst_feature immediate-relation MtLv2.pageblocks5cn01nccsv_attrinst_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrinst_feature q-location MtLv2.pageblocks5cn01nccsv_attrinst_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_nunique_feature immediate-relation MtLv2.HTRU2csv_nunique_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_nunique_feature q-location MtLv2.HTRU2csv_nunique_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrent_feature immediate-relation MtLv2.ckddatasetv2csv_attrent_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrent_feature q-location MtLv2.ckddatasetv2csv_attrent_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_labelissuesperc_feature immediate-relation MtLv2.HTRU2csv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_labelissuesperc_feature q-location MtLv2.HTRU2csv_labelissuesperc_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nrInst_feature immediate-relation MtLv2.yeast2vs4csv_nrInst_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nrInst_feature q-location MtLv2.yeast2vs4csv_nrInst_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nunique_feature immediate-relation MtLv2.yeast2vs4csv_nunique_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nunique_feature q-location MtLv2.yeast2vs4csv_nunique_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nrInst_feature immediate-relation MtLv2.pageblocks5cn01nccsv_nrInst_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nrInst_feature q-location MtLv2.pageblocks5cn01nccsv_nrInst_mean
# * Owlready * Adding relation MtLv2.ecolidata_nrcorattr_feature immediate-relation MtLv2.ecolidata_nrcorattr_mean
# * Owlready * Adding relation MtLv2.ecolidata_nrcorattr_feature q-location MtLv2.ecolidata_nrcorattr_mean
# * Owlready * Adding relation MtLv2.ecolidata_ena_feature immediate-relation MtLv2.ecolidata_ena_mean
# * Owlready * Adding relation MtLv2.ecolidata_ena_feature q-location MtLv2.ecolidata_ena_mean
# * Owlready * Adding relation MtLv2.ecolidata_attrconc_feature immediate-relation MtLv2.ecolidata_attrconc_mean
# * Owlready * Adding relation MtLv2.ecolidata_attrconc_feature q-location MtLv2.ecolidata_attrconc_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrconc_feature immediate-relation MtLv2.pageblocks5cn01nccsv_attrconc_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrconc_feature q-location MtLv2.pageblocks5cn01nccsv_attrconc_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_nrInst_feature immediate-relation MtLv2.HTRU2csv_nrInst_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_nrInst_feature q-location MtLv2.HTRU2csv_nrInst_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_conciseness_feature immediate-relation MtLv2.ckddatasetv2csv_conciseness_mean
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_conciseness_feature q-location MtLv2.ckddatasetv2csv_conciseness_mean
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_attrent_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_nrInst_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_nunique_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_attrconc_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_range_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_ena_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_conciseness_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_gmean_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_tmean_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_eigen_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_centropy_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv immediate-relation-i MtLv2.pageblocks5cn01nccsv_attrinst_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_labelissuesperc_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_attrent_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_nrInst_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_nunique_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_attrconc_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_range_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_ena_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_conciseness_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_gmean_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_tmean_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_nrcorattr_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_eigen_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_centropy_feature
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv has-quality MtLv2.pageblocks5cn01nccsv_attrinst_feature
# * Owlready * Adding relation MtLv2.HTRU2csv_centropy_feature immediate-relation MtLv2.HTRU2csv_centropy_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_centropy_feature q-location MtLv2.HTRU2csv_centropy_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_conciseness_feature immediate-relation MtLv2.HTRU2csv_conciseness_mean
# * Owlready * Adding relation MtLv2.HTRU2csv_conciseness_feature q-location MtLv2.HTRU2csv_conciseness_mean
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrent_mean hasDataValue 2.0698346406448302
# * Owlready * Adding relation MtLv2.HTRU2csv_nunique_mean hasDataValue 2
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nrcorattr_mean hasDataValue 0.058201058201058
# * Owlready * Adding relation MtLv2.ecolidata_conciseness_mean hasDataValue 0.0
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nrInst_mean hasDataValue 5472
# * Owlready * Adding relation MtLv2.HTRU2csv_ena_mean hasDataValue 0.28345279418651304
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrconc_mean hasDataValue 0.015496553734223999
# * Owlready * Adding relation MtLv2.ecolidata_nrInst_mean hasDataValue 335
# * Owlready * Adding relation MtLv2.HTRU2csv_attrent_mean hasDataValue 4.700437176373519
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nrcorattr_mean hasDataValue 0.035714285714286004
# * Owlready * Adding relation MtLv2.yeast2vs4csv_eigen_mean hasDataValue 0.007934818502969
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_tmean_mean hasDataValue 101.406805785627
# * Owlready * Adding relation MtLv2.ecolidata_attrinst_mean hasDataValue 0.026865671641791003
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_range_mean hasDataValue 23318.6879
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nunique_mean hasDataValue 2
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrconc_mean hasDataValue 0.08867033715194698
# * Owlready * Adding relation MtLv2.yeast2vs4csv_gmean_mean hasDataValue 0.309456932155932
# * Owlready * Adding relation MtLv2.HTRU2csv_range_mean hasDataValue 237.219778998125
# * Owlready * Adding relation MtLv2.HTRU2csv_attrinst_mean hasDataValue 0.00044697731590099995
# * Owlready * Adding relation MtLv2.ecolidata_attrconc_mean hasDataValue 0.05241064483440001
# * Owlready * Adding relation MtLv2.yeast2vs4csv_range_mean hasDataValue 0.7
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrconc_mean hasDataValue 0.060208314451449994
# * Owlready * Adding relation MtLv2.yeast2vs4csv_nrInst_mean hasDataValue 514
# * Owlready * Adding relation MtLv2.yeast2vs4csv_attrinst_mean hasDataValue 0.015564202334629998
# * Owlready * Adding relation MtLv2.ecolidata_tmean_mean hasDataValue 37.4912935323383
# * Owlready * Adding relation MtLv2.yeast2vs4csv_labelissuesperc_mean hasDataValue 0.003891050583658
# * Owlready * Adding relation MtLv2.HTRU2csv_eigen_mean hasDataValue 1669.6855647064801
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrinst_mean hasDataValue 0.001827485380117
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nunique_mean hasDataValue 10
# * Owlready * Adding relation MtLv2.yeast2vs4csv_centropy_mean hasDataValue 0.466523860691863
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_eigen_mean hasDataValue 1.86013460157932
# * Owlready * Adding relation MtLv2.ecolidata_eigen_mean hasDataValue 2084.4637373805604
# * Owlready * Adding relation MtLv2.HTRU2csv_tmean_mean hasDataValue 34.7606163025099
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_ena_mean hasDataValue -0.62924274428714
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_gmean_mean hasDataValue 81.5342505194476
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_conciseness_mean hasDataValue 0.012061403508772
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_labelissuesperc_mean hasDataValue 0.049707602339181
# * Owlready * Adding relation MtLv2.yeast2vs4csv_ena_mean hasDataValue 5.3543409471717105
# * Owlready * Adding relation MtLv2.ecolidata_range_mean hasDataValue 74.8433333333333
# * Owlready * Adding relation MtLv2.HTRU2csv_nrInst_mean hasDataValue 17898
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_labelissuesperc_mean hasDataValue 0.01
# * Owlready * Adding relation MtLv2.HTRU2csv_labelissuesperc_mean hasDataValue 0.00011174432897499998
# * Owlready * Adding relation MtLv2.ecolidata_nunique_mean hasDataValue 8
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nunique_mean hasDataValue 5
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrinst_mean hasDataValue 0.14
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_nrcorattr_mean hasDataValue 0.288888888888889
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_centropy_mean hasDataValue 0.88640258325904
# * Owlready * Adding relation MtLv2.ecolidata_nrcorattr_mean hasDataValue 0.083333333333333
# * Owlready * Adding relation MtLv2.yeast2vs4csv_conciseness_mean hasDataValue 0.04863813229572
# * Owlready * Adding relation MtLv2.ecolidata_gmean_mean hasDataValue 0.21332340096444197
# * Owlready * Adding relation MtLv2.HTRU2csv_conciseness_mean hasDataValue 0.0
# * Owlready * Adding relation MtLv2.HTRU2csv_gmean_mean hasDataValue 0.0
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_centropy_mean hasDataValue 0.273259338498887
# * Owlready * Adding relation MtLv2.ecolidata_attrent_mean hasDataValue 2.03306866759679
# * Owlready * Adding relation MtLv2.ecolidata_centropy_mean hasDataValue 0.730530510128212
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_eigen_mean hasDataValue 2872230.81344716
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_nrInst_mean hasDataValue 200
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_attrent_mean hasDataValue 1.10918255526766
# * Owlready * Adding relation MtLv2.HTRU2csv_nrcorattr_mean hasDataValue 0.3928571428571429
# * Owlready * Adding relation MtLv2.yeast2vs4csv_tmean_mean hasDataValue 0.36786290322580606
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_range_mean hasDataValue 3.89285714285714
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_gmean_mean hasDataValue 0.0
# * Owlready * Adding relation MtLv2.HTRU2csv_attrconc_mean hasDataValue 0.082788274628588
# * Owlready * Adding relation MtLv2.pageblocks5cn01nccsv_attrent_mean hasDataValue 3.99185335985919
# * Owlready * Adding relation MtLv2.ecolidata_labelissuesperc_mean hasDataValue 0.05970149253731401
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_tmean_mean hasDataValue 1.9476190476190502
# * Owlready * Adding relation MtLv2.ecolidata_ena_mean hasDataValue -25.495713910915605
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_conciseness_mean hasDataValue 0.0
# * Owlready * Adding relation MtLv2.HTRU2csv_centropy_mean hasDataValue 0.441703497737403
# * Owlready * Adding relation MtLv2.ckddatasetv2csv_ena_mean hasDataValue -5.7081161515242895
# ✅ Ontology is consistent.
# * Owlready2 * Pellet took 17.233116626739502 seconds
# * Owlready * Reparenting DMOP.NumberOfInstances: {DMOP.DataSetCharacteristic} => {DMOP.DataCharacteristic}
# * Owlready * Reparenting MtLv2.MIMean1: {DMOP.DataCharacteristic} => {DMOP.NumberOfInstances}
# * Owlready * Reparenting MtLv2.ReliefMean1: {DMOP.DataCharacteristic} => {DMOP.NumberOfInstances}
# * Owlready * Reparenting MtLv2.HTRU2csv_nrInst_feature: {DMOP.NumberOfInstances} => {MtLv2.ReliefMean1}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_nrInst_feature: {DMOP.NumberOfInstances} => {MtLv2.ReliefMean1}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_nrInst_feature: {DMOP.NumberOfInstances} => {MtLv2.ReliefMean1}
# * Owlready * Reparenting MtLv2.GRMean1: {DMOP.DataCharacteristic} => {MtLv2.ReliefMean1}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_nrInst_feature: {DMOP.NumberOfInstances} => {MtLv2.GRMean1}
# * Owlready * Reparenting MtLv2.ecolidata_nrInst_feature: {DMOP.NumberOfInstances} => {MtLv2.GRMean1}
# * Owlready * Reparenting MtLv2.MIMean3: {DMOP.DataCharacteristic} => {MtLv2.AttributeConcentration}
# * Owlready * Reparenting MtLv2.HTRU2csv_attrconc_feature: {MtLv2.AttributeConcentration} => {MtLv2.MIMean3}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_attrconc_feature: {MtLv2.AttributeConcentration} => {MtLv2.MIMean3}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_attrconc_feature: {MtLv2.AttributeConcentration} => {MtLv2.MIMean3}
# * Owlready * Reparenting MtLv2.ChisquareMean2: {DMOP.DataCharacteristic} => {MtLv2.AttributesEntropy}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_attrent_feature: {MtLv2.AttributesEntropy} => {MtLv2.ChisquareMean2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_attrent_feature: {MtLv2.AttributesEntropy} => {MtLv2.ChisquareMean2}
# * Owlready * Reparenting MtLv2.ecolidata_attrent_feature: {MtLv2.AttributesEntropy} => {MtLv2.ChisquareMean2}
# * Owlready * Reparenting MtLv2.ChisquareMean3: {DMOP.DataCharacteristic} => {MtLv2.ClassEntropy}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_centropy_feature: {MtLv2.ClassEntropy} => {MtLv2.ChisquareMean3, MtLv2.ReliefMean7}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_centropy_feature: {MtLv2.ClassEntropy} => {MtLv2.ChisquareMean3, MtLv2.ReliefMean7}
# * Owlready * Reparenting MtLv2.HTRU2csv_centropy_feature: {MtLv2.ClassEntropy} => {MtLv2.ChisquareMean3, MtLv2.ReliefMean7}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_centropy_feature: {MtLv2.ClassEntropy} => {MtLv2.ChisquareMean3}
# * Owlready * Reparenting MtLv2.ecolidata_centropy_feature: {MtLv2.ClassEntropy} => {MtLv2.ChisquareMean3, MtLv2.ReliefMean7}
# * Owlready * Reparenting MtLv2.ReliefMean7: {DMOP.DataCharacteristic} => {MtLv2.ClassEntropy}
# * Owlready * Reparenting MtLv2.ChisquareMean1: {DMOP.DataCharacteristic} => {MtLv2.Conciseness}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_conciseness_feature: {MtLv2.Conciseness} => {MtLv2.ChisquareMean1}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_conciseness_feature: {MtLv2.Conciseness} => {MtLv2.ChisquareMean1}
# * Owlready * Reparenting MtLv2.ecolidata_conciseness_feature: {MtLv2.Conciseness} => {MtLv2.ChisquareMean1}
# * Owlready * Reparenting MtLv2.HTRU2csv_conciseness_feature: {MtLv2.Conciseness} => {MtLv2.ChisquareMean1}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_conciseness_feature: {MtLv2.Conciseness} => {MtLv2.ChisquareMean1}
# * Owlready * Reparenting MtLv2.FCBFMean3: {DMOP.DataCharacteristic} => {MtLv2.Conciseness}
# * Owlready * Reparenting MtLv2.GRMean4: {DMOP.DataCharacteristic} => {MtLv2.LabelNoise}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_labelissuesperc_feature: {MtLv2.LabelNoise} => {MtLv2.GRMean4}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_labelissuesperc_feature: {MtLv2.LabelNoise} => {MtLv2.GRMean4}
# * Owlready * Reparenting MtLv2.ecolidata_labelissuesperc_feature: {MtLv2.LabelNoise} => {MtLv2.GRMean4}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_labelissuesperc_feature: {MtLv2.LabelNoise} => {MtLv2.GRMean4}
# * Owlready * Reparenting MtLv2.HTRU2csv_labelissuesperc_feature: {MtLv2.LabelNoise} => {MtLv2.GRMean4}
# * Owlready * Reparenting MtLv2.ReliefMean6: {DMOP.DataCharacteristic} => {MtLv2.OutlierDetection}
# * Owlready * Reparenting MtLv2.MIMean2: {DMOP.DataCharacteristic} => {MtLv2.EigenValues}
# * Owlready * Reparenting MtLv2.HTRU2csv_eigen_feature: {MtLv2.EigenValues} => {MtLv2.MIMean2}
# * Owlready * Reparenting MtLv2.ecolidata_eigen_feature: {MtLv2.EigenValues} => {MtLv2.MIMean2}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_eigen_feature: {MtLv2.EigenValues} => {MtLv2.MIMean2}
# * Owlready * Reparenting MtLv2.FCBFMean2: {DMOP.DataCharacteristic} => {MtLv2.EqNumberOfAttributes}
# * Owlready * Reparenting MtLv2.GRMean5: {DMOP.DataCharacteristic} => {MtLv2.FCBFMean2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_ena_feature: {MtLv2.EqNumberOfAttributes} => {MtLv2.GRMean5}
# * Owlready * Reparenting MtLv2.HTRU2csv_ena_feature: {MtLv2.EqNumberOfAttributes} => {MtLv2.ReliefMean8, MtLv2.GRMean5}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_ena_feature: {MtLv2.EqNumberOfAttributes} => {MtLv2.ReliefMean8, MtLv2.GRMean5}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_ena_feature: {MtLv2.EqNumberOfAttributes} => {MtLv2.ReliefMean8, MtLv2.GRMean5}
# * Owlready * Reparenting MtLv2.ReliefMean8: {DMOP.DataCharacteristic} => {MtLv2.EqNumberOfAttributes}
# * Owlready * Reparenting MtLv2.ecolidata_ena_feature: {MtLv2.EqNumberOfAttributes} => {MtLv2.ReliefMean8}
# * Owlready * Reparenting MtLv2.ReliefMean4: {DMOP.DataCharacteristic} => {MtLv2.GeometricMean}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_gmean_feature: {MtLv2.GeometricMean} => {MtLv2.ReliefMean4}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_gmean_feature: {MtLv2.GeometricMean} => {MtLv2.ReliefMean4}
# * Owlready * Reparenting MtLv2.MutualInformation: {DMOP.DataSetCharacteristic} => {DMOP.DataSetCharacteristic, MtLv2.FSTechniques}
# * Owlready * Reparenting MtLv2.FCBFMean1: {DMOP.DataCharacteristic} => {MtLv2.NumberOfClasses}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_nunique_feature: {MtLv2.NumberOfClasses} => {MtLv2.FCBFMean1}
# * Owlready * Reparenting MtLv2.GRMean2: {DMOP.DataCharacteristic} => {MtLv2.FCBFMean1}
# * Owlready * Reparenting MtLv2.HTRU2csv_nunique_feature: {MtLv2.NumberOfClasses} => {MtLv2.GRMean2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_nunique_feature: {MtLv2.NumberOfClasses} => {MtLv2.GRMean2}
# * Owlready * Reparenting MtLv2.ReliefMean2: {DMOP.DataCharacteristic} => {MtLv2.NumberOfClasses}
# * Owlready * Reparenting MtLv2.ecolidata_nunique_feature: {MtLv2.NumberOfClasses} => {MtLv2.ReliefMean2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_nunique_feature: {MtLv2.NumberOfClasses} => {MtLv2.ReliefMean2}
# * Owlready * Reparenting MtLv2.ReliefMean3: {DMOP.DataCharacteristic} => {MtLv2.NumberOfHighlyCorrelatedAttributes}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_nrcorattr_feature: {MtLv2.NumberOfHighlyCorrelatedAttributes} => {MtLv2.ReliefMean3}
# * Owlready * Reparenting MtLv2.ChisquareMean5: {DMOP.DataCharacteristic} => {MtLv2.ProportionOfAttrToInstances}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_attrinst_feature: {MtLv2.ProportionOfAttrToInstances} => {MtLv2.ChisquareMean5}
# * Owlready * Reparenting MtLv2.ecolidata_attrinst_feature: {MtLv2.ProportionOfAttrToInstances} => {MtLv2.ChisquareMean5}
# * Owlready * Reparenting MtLv2.HTRU2csv_attrinst_feature: {MtLv2.ProportionOfAttrToInstances} => {MtLv2.ChisquareMean5}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_attrinst_feature: {MtLv2.ProportionOfAttrToInstances} => {MtLv2.ChisquareMean5}
# * Owlready * Reparenting MtLv2.ChisquareMean4: {DMOP.DataCharacteristic} => {MtLv2.Range}
# * Owlready * Reparenting MtLv2.HTRU2csv_range_feature: {MtLv2.Range} => {MtLv2.ChisquareMean4}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_range_feature: {MtLv2.Range} => {MtLv2.ChisquareMean4}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_range_feature: {MtLv2.Range} => {MtLv2.ChisquareMean4}
# * Owlready * Reparenting MtLv2.ecolidata_range_feature: {MtLv2.Range} => {MtLv2.ChisquareMean4}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_range_feature: {MtLv2.Range} => {MtLv2.ChisquareMean4}
# * Owlready * Reparenting MtLv2.GRMean3: {DMOP.DataCharacteristic} => {MtLv2.TrimmedMean}
# * Owlready * Reparenting MtLv2.ecolidata_tmean_feature: {MtLv2.TrimmedMean} => {MtLv2.GRMean3}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_tmean_feature: {MtLv2.TrimmedMean} => {MtLv2.GRMean3}
# * Owlready * Reparenting MtLv2.HTRU2csv_tmean_feature: {MtLv2.TrimmedMean} => {MtLv2.GRMean3}
# * Owlready * Reparenting MtLv2.ReliefMean5: {DMOP.DataCharacteristic} => {MtLv2.TrimmedMean}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_tmean_feature: {MtLv2.TrimmedMean} => {MtLv2.ReliefMean5}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_tmean_feature: {MtLv2.TrimmedMean} => {MtLv2.ReliefMean5}
# * Owlready * Reparenting MtLv2.yeast2vs4csv: {DMOP.LabeledDataSet, MtLv2.FeatureSelectionRecommendationTask, MtLv2.LearningFromTaskProperties, MtLv2.FeatureSelectionRecommendation} => {MtLv2.FeatureSelectionRecommendation, MtLv2.FeatureSelectionRecommendationTask, MtLv2.ChisquareRelevantData, MtLv2.LearningFromTaskProperties}
# * Owlready * Reparenting MtLv2.HTRU2csv_tmean_mean: {MtLv2.Mean} => {MtLv2.MIConstraintsEigen, MtLv2.MIConstraintsInstances1}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_gmean_mean: {MtLv2.Mean} => {MtLv2.MIConstraintsEigen, MtLv2.MIConstraintsInstances1}
# * Owlready * Reparenting MtLv2.ecolidata_range_mean: {MtLv2.Mean} => {MtLv2.MIConstraintsEigen, MtLv2.MIConstraintsInstances1}
# * Owlready * Reparenting MtLv2.ecolidata_tmean_mean: {MtLv2.Mean} => {MtLv2.MIConstraintsEigen, MtLv2.MIConstraintsInstances1}
# * Owlready * Reparenting MtLv2.MIConstraintsInstances2: {MtLv2.Mean} => {MtLv2.MIConstraintsEigen, MtLv2.MIConstraintsInstances1}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_tmean_mean: {MtLv2.Mean} => {MtLv2.MIConstraintsInstances2}
# * Owlready * Reparenting MtLv2.ReliefConstraintsTMean: {MtLv2.Mean} => {MtLv2.MIConstraintsInstances1}
# * Owlready * Reparenting MtLv2.ecolidata_nunique_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsTMean, MtLv2.ReliefConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_nunique_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsTMean, MtLv2.ReliefConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.FCBFConstraintsNoClasses: {MtLv2.Mean} => {MtLv2.ReliefConstraintsTMean}
# * Owlready * Reparenting MtLv2.HTRU2csv_attrent_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsNoClasses, MtLv2.ChisquareConstraintsRange}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_ena_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsNoClasses, MtLv2.ChisquareConstraintsRange}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_nunique_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsNoClasses, MtLv2.ChisquareConstraintsRange}
# * Owlready * Reparenting MtLv2.GRConstraintsNoClasses: {MtLv2.Mean} => {MtLv2.FCBFConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_range_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.GRConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_attrent_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.GRConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.ChisquareConstraintsAttrEnt: {MtLv2.Mean} => {MtLv2.GRConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.ChisquareConstraintsCEnt: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsAttrEnt}
# * Owlready * Reparenting MtLv2.ecolidata_centropy_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ChisquareConstraintsCEnt, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_range_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ChisquareConstraintsCEnt, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_centropy_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ChisquareConstraintsCEnt, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_centropy_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsCEntropy, MtLv2.ReliefConstraintsENA2, MtLv2.ChisquareConstraintsCEnt}
# * Owlready * Reparenting MtLv2.HTRU2csv_centropy_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsCEntropy, MtLv2.ReliefConstraintsENA2, MtLv2.ChisquareConstraintsCEnt}
# * Owlready * Reparenting MtLv2.ChisquareConstraintsConc: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsCEnt}
# * Owlready * Reparenting MtLv2.HTRU2csv_attrconc_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsConc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_attrinst_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsConc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_attrconc_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsConc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ecolidata_nrcorattr_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsConc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ecolidata_gmean_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsConc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ChisquareConstraintsAttrInst: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsConc}
# * Owlready * Reparenting MtLv2.GRConstrainsLabelIssuesPerc: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsAttrInst}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_nrcorattr_mean: {MtLv2.Mean} => {MtLv2.GRConstrainsLabelIssuesPerc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ecolidata_attrconc_mean: {MtLv2.Mean} => {MtLv2.GRConstrainsLabelIssuesPerc, MtLv2.ReliefConstraintsNoOfOutliers, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_attrconc_mean: {MtLv2.Mean} => {MtLv2.GRConstrainsLabelIssuesPerc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ecolidata_labelissuesperc_mean: {MtLv2.Mean} => {MtLv2.GRConstrainsLabelIssuesPerc, MtLv2.ReliefConstraintsENA2, MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ReliefNumberofCorr: {MtLv2.Mean} => {MtLv2.GRConstrainsLabelIssuesPerc}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_labelissuesperc_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.HTRU2csv_labelissuesperc_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_gmean_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.HTRU2csv_gmean_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ecolidata_attrinst_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.ReliefConstraintsNoOfOutliers, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_labelissuesperc_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ecolidata_conciseness_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_ena_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_conciseness_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_attrinst_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_labelissuesperc_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.ReliefConstraintsNoOfOutliers, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_attrconc_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ecolidata_ena_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_nrcorattr_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.ReliefConstraintsNoOfOutliers, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_eigen_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_conciseness_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.HTRU2csv_attrinst_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_attrinst_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_ena_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_conciseness_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.ReliefConstraintsNoOfOutliers, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.HTRU2csv_conciseness_mean: {MtLv2.Mean} => {MtLv2.ReliefNumberofCorr, MtLv2.GRConstraintsENA, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.FCBFConstraintsConc2: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc1, MtLv2.ReliefConstraintsENA2, MtLv2.ChisquareConstraintsCEnt}
# * Owlready * Reparenting MtLv2.HTRU2csv_ena_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc2, MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_centropy_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc2, MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_gmean_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc2, MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.HTRU2csv_nrcorattr_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc2, MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_nrcorattr_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc2, MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_tmean_mean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc2, MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.ReliefConstraintsENA2: {MtLv2.Mean} => {MtLv2.ReliefConstraintsENA1, MtLv2.ChisquareConstraintsAttrEnt}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_attrent_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.HTRU2csv_nunique_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_eigen_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_nunique_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ecolidata_attrent_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_attrent_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_tmean_mean: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange, MtLv2.ReliefConstraintsENA2}
# * Owlready * Reparenting MtLv2.FCBFConstraintsENA: {MtLv2.Mean} => {MtLv2.ReliefConstraintsENA1}
# * Owlready * Reparenting MtLv2.GRConstraintsENA: {MtLv2.Mean} => {MtLv2.FCBFConstraintsENA}
# * Owlready * Reparenting MtLv2.ReliefConstraintsNoOfOutliers: {MtLv2.Mean} => {MtLv2.GRConstraintsENA}
# * Owlready * Reparenting MtLv2.MIConstraintsAttr: {MtLv2.Mean} => {MtLv2.ReliefConstraintsNoOfOutliers}
# * Owlready * Reparenting MtLv2.FCBFConstraintsConc1: {MtLv2.Mean} => {MtLv2.MIConstraintsAttr}
# * Owlready * Reparenting MtLv2.ReliefGMean: {MtLv2.Mean} => {MtLv2.FCBFConstraintsConc1}
# * Owlready * Reparenting MtLv2.ReliefConstraintsCEntropy: {MtLv2.Mean} => {MtLv2.ReliefGMean}
# * Owlready * Reparenting MtLv2.ChisquareConstraintsRange: {MtLv2.Mean} => {MtLv2.ReliefConstraintsCEntropy}
# * Owlready * Reparenting MtLv2.ReliefConstraintsNoClasses: {MtLv2.Mean} => {MtLv2.ChisquareConstraintsRange}
# * Owlready * Reparenting MtLv2.GRConstrainsTMean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsNoClasses}
# * Owlready * Reparenting MtLv2.MIConstraintsEigen: {MtLv2.Mean} => {MtLv2.GRConstrainsTMean}
# * Owlready * Reparenting MtLv2.ReliefConstraintsInstances: {MtLv2.Mean} => {MtLv2.MIConstraintsEigen}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_range_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_nrInst_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.ecolidata_eigen_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.yeast2vs4csv_nrInst_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.HTRU2csv_eigen_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.pageblocks5cn01nccsv_eigen_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.HTRU2csv_nrInst_mean: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.GRConstraintsInstances2: {MtLv2.Mean} => {MtLv2.ReliefConstraintsInstances}
# * Owlready * Reparenting MtLv2.ckddatasetv2csv_nrInst_mean: {MtLv2.Mean} => {MtLv2.GRConstraintsInstances2}
# * Owlready * Reparenting MtLv2.ecolidata_nrInst_mean: {MtLv2.Mean} => {MtLv2.GRConstraintsInstances2}
# * Owlready * Reparenting MtLv2.HTRU2csv_range_mean: {MtLv2.Mean} => {MtLv2.GRConstraintsInstances2}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %%
# Check classification again just to be safe

for fileName, fileObject in fileObjects.items():
    #print(fileName, fileObject)
    flag=1
    if onto.MIRelevantData in fileObject.is_a:
        output = onto.MITask.specifiesOutputClass
        print(f"{fileObject.name} satisfies MIRelevantData constraint", output[0].recommends)
        flag=0
    if onto.FCBFRelevantData in fileObject.is_a:
        output = onto.FCBFTask.specifiesOutputClass
        print(f"{fileObject.name} satisfies FCBFRelevantData constraint", output[0].recommends)
        flag=0
    if onto.GRRelevantData in fileObject.is_a:
        output = onto.GRTask.specifiesOutputClass
        print(f"{fileObject.name} satisfies GRRelevantData constraint", output[0].recommends)
        flag=0
    if onto.Relief1RelevantData in fileObject.is_a:
        output = onto.Relief1Task.specifiesOutputClass
        print(f"{fileObject.name} satisfies ReliefRelevantData constraint", output[0].recommends)
        flag=0
    if onto.Relief2RelevantData in fileObject.is_a:
        output = onto.Relief1Task.specifiesOutputClass
        print(f"{fileObject.name} satisfies ReliefRelevantData constraint", output[0].recommends)
        flag=0
    if onto.ChisquareRelevantData in fileObject.is_a:
        output = onto.ChisquareTask.specifiesOutputClass
        print(f"{fileObject.name} satisfies ChisquareRelevantData constraint", output[0].recommends)
        flag=0
    if(flag==1): 
        print("NO RECOMMENDATION")
# Out:
# yeast2vs4csv satisfies ChisquareRelevantData constraint [MtLv2.ChiSquare]
# NO RECOMMENDATION
# NO RECOMMENDATION
# NO RECOMMENDATION
# NO RECOMMENDATION

# %%
from rdflib import Graph, Namespace, Literal, RDF, XSD
from pyshacl import validate

# %%
# SHACL shapes
shapes = Graph()
shapes.parse(data="""
@prefix sh: <http://www.w3.org/ns/shacl#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix ex: <http://example.org/> .

ex:NRInstShape a sh:NodeShape ;
    sh:targetClass ex:DataSet ;
    sh:property [
        sh:path ex:nr_inst ;
        sh:datatype xsd:float ;
        sh:or (
            [ sh:maxInclusive 167.0 ]
            [ sh:minExclusive 167.0 ]
        ) ;
        sh:message "nr_inst must be either <= 167 or > 167, not both." ;
    ] .

ex:NUniqueShape a sh:NodeShape ;
    sh:targetClass ex:DataSet ;
    sh:property [
        sh:path ex:nUnique ;
        sh:datatype xsd:float ;
        sh:or (
            [ sh:maxInclusive 6.5 ]
            [ sh:minExclusive 6.5 ]
        ) ;
        sh:message "nUnique must be either <= 6.5 or > 6.5, not both." ;
    ] .
""", format="turtle")

# Run validation
conforms, report_graph, report_text = validate(
    data_graph=g,
    shacl_graph=shapes,
    inference='rdfs',
    abort_on_error=False,
    meta_shacl=False,
    advanced=True
)

print("SHACL Validation Report:")
print(report_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d1f913f32bbf> in <module>
#      33 # Run validation
#      34 conforms, report_graph, report_text = validate(
# ---> 35     data_graph=g,
#      36     shacl_graph=shapes,
#      37     inference='rdfs',
#
# NameError: name 'g' is not defined
